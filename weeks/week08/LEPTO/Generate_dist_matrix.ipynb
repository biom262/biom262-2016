# %%
#%%bash 
#pruning lepto data
#export pwd=`pwd`

#/projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --indep-pairwise 50 5 0.1 
#/projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --extract plink.prune.in --make-bed --out lepto_fin_pruned

# %%
# %%bash
#
# #extracting most variable selected chromosomes 17,20,21,22
#
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --chr 17 --make-bed --out lepto_selected_chr_17
#
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --chr 20 --make-bed --out lepto_selected_chr_20
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --chr 21 --make-bed --out lepto_selected_chr_21
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --chr 22 --make-bed --out lepto_selected_chr_22
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto_selected_chr_17 --bmerge lepto_selected_chr_20.bed lepto_selected_chr_20.bim lepto_selected_chr_20.fam --make-bed --out m1
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile m1 --bmerge lepto_selected_chr_21.bed lepto_selected_chr_21.bim lepto_selected_chr_21.fam --make-bed --out m2
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile m2 --bmerge lepto_selected_chr_22.bed lepto_selected_chr_22.bim lepto_selected_chr_22.fam --make-bed --out lepto_selected_chr
# Out:
# @----------------------------------------------------------@
# |        PLINK!       |     v1.07      |   10/Aug/2009     |
# |----------------------------------------------------------|
# |  (C) 2009 Shaun Purcell, GNU General Public License, v2  |
# |----------------------------------------------------------|
# |  For documentation, citation & bug-report instructions:  |
# |        http://pngu.mgh.harvard.edu/purcell/plink/        |
# @----------------------------------------------------------@
#
# Skipping web check... [ --noweb ]
# Writing this text to log file [ lepto_selected_chr_17.log ]
# Analysis started: Tue Mar 15 03:12:31 2016
#
# Options in effect:
# 	--noweb
# 	--bfile lepto
# 	--chr 17
# 	--make-bed
# 	--out lepto_selected_chr_17
#
# Reading map (extended format) from [ lepto.bim ]
# 181906 markers to be included from [ lepto.bim ]
# Scan region on chromosome 17 from [ rs8078929 ] to [ rs7224733 ]
# Reading pedigree information from [ lepto.fam ]
# ...

# %%
#%%bash
#merging two ped files

#/projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto --bmerge lepto_unrel.bed lepto_unrel.bim lepto_unrel.fam --make-bed --out merge 

'''both files appear to be the same individuals'''

# %%
# %%bash
# #pruning lepto_selected_chr data to remove linkage disequilibrium
#
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto_selected_chr --indep-pairwise 50 5 0.1
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto_selected_chr --extract plink.prune.in --make-bed --out lepto_selected_chr_pruned
# Out:
# @----------------------------------------------------------@
# |        PLINK!       |     v1.07      |   10/Aug/2009     |
# |----------------------------------------------------------|
# |  (C) 2009 Shaun Purcell, GNU General Public License, v2  |
# |----------------------------------------------------------|
# |  For documentation, citation & bug-report instructions:  |
# |        http://pngu.mgh.harvard.edu/purcell/plink/        |
# @----------------------------------------------------------@
#
# Skipping web check... [ --noweb ]
# Writing this text to log file [ plink.log ]
# Analysis started: Tue Mar 15 03:12:49 2016
#
# Options in effect:
# 	--noweb
# 	--bfile lepto_selected_chr
# 	--indep-pairwise 50 5 0.1
#
# Reading map (extended format) from [ lepto_selected_chr.bim ]
# 13380 markers to be included from [ lepto_selected_chr.bim ]
# Reading pedigree information from [ lepto_selected_chr.fam ]
# 266 individuals read from [ lepto_selected_chr.fam ]
# ...

# %%
#%%bash

#pruning unrel data

#export pwd=`pwd`

#$pwd/plink-1.07-x86_64/plink --noweb --bfile LEPTO/lepto_unrel --indep-pairwise 50 5 0.1 
#$pwd/plink-1.07-x86_64/plink --noweb --bfile LEPTO/lepto_unrel --extract plink.prune.in --make-bed --out LEPTO/lepto_unrel_fin_pruned

# %%
#%%bash

#create IBS matrix

#export pwd=`pwd`

#$pwd/plink-1.07-x86_64/plink --noweb --bfile LEPTO/lepto_fin_pruned --cluster --distance-matrix --out LEPTO/lepto_fin_pruned
#$pwd/plink-1.07-x86_64/plink --noweb --bfile LEPTO/lepto_clean_fin_pruned --cluster --distance-matrix --out LEPTO/lepto_clean_fin_pruned
#$pwd/plink-1.07-x86_64/plink --noweb --bfile LEPTO/lepto_unrel_fin_pruned --cluster --distance-matrix --out LEPTO/lepto_unrel_fin_pruned

# %%
# %%bash
# #Generating IBS matrix using lepto_selected_chr_pruned for PcoA
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --noweb --bfile lepto_selected_chr_pruned --cluster --distance-matrix --out lepto_selected_chr_pruned
# Out:
# @----------------------------------------------------------@
# |        PLINK!       |     v1.07      |   10/Aug/2009     |
# |----------------------------------------------------------|
# |  (C) 2009 Shaun Purcell, GNU General Public License, v2  |
# |----------------------------------------------------------|
# |  For documentation, citation & bug-report instructions:  |
# |        http://pngu.mgh.harvard.edu/purcell/plink/        |
# @----------------------------------------------------------@
#
# Skipping web check... [ --noweb ]
# Writing this text to log file [ lepto_selected_chr_pruned.log ]
# Analysis started: Tue Mar 15 03:12:58 2016
#
# Options in effect:
# 	--noweb
# 	--bfile lepto_selected_chr_pruned
# 	--cluster
# 	--distance-matrix
# 	--out lepto_selected_chr_pruned
#
# Reading map (extended format) from [ lepto_selected_chr_pruned.bim ]
# 3107 markers to be included from [ lepto_selected_chr_pruned.bim ]
# ...

# %%
# %%bash
# #Principal component analysis on pruned selected chromosomes using gcta64 toolkit
#
# /projects/ps-yeolab/biom262_2016/tools/gcta64 --bfile lepto_selected_chr_pruned --make-grm --out lepto_selected_chr_pruned
#
# /projects/ps-yeolab/biom262_2016/tools/gcta64 --grm lepto_selected_chr_pruned --pca 2 --out lepto_selected_chr_pruned
# Out:
# *******************************************************************
# * Genome-wide Complex Trait Analysis (GCTA)
# * version 1.25.2
# * (C) 2010-2013 Jian Yang, Hong Lee, Michael Goddard and Peter Visscher
# * The University of Queensland
# * MIT License
# *******************************************************************
# Analysis started: Tue Mar 15 03:13:25 2016
#
# Options:
# --bfile lepto_selected_chr_pruned
# --make-grm
# --out lepto_selected_chr_pruned
#
# Note: This is a multi-thread program. You could specify the number of threads by the --thread-num option to speed up the computation if there are multiple processors in your machine.
#
# Reading PLINK FAM file from [lepto_selected_chr_pruned.fam].
# 266 individuals to be included from [lepto_selected_chr_pruned.fam].
# Reading PLINK BIM file from [lepto_selected_chr_pruned.bim].
# 3107 SNPs to be included from [lepto_selected_chr_pruned.bim].
# ...

# %%
# %%bash
# #association analysis
#
# /projects/ps-yeolab/biom262_2016/tools/plink-1.07-x86_64/plink --bfile lepto_selected_chr_pruned --assoc
# Out:
# @----------------------------------------------------------@
# |        PLINK!       |     v1.07      |   10/Aug/2009     |
# |----------------------------------------------------------|
# |  (C) 2009 Shaun Purcell, GNU General Public License, v2  |
# |----------------------------------------------------------|
# |  For documentation, citation & bug-report instructions:  |
# |        http://pngu.mgh.harvard.edu/purcell/plink/        |
# @----------------------------------------------------------@
#
# Web-based version check ( --noweb to skip )
# Recent cached web-check found...Problem connecting to web
#
# Writing this text to log file [ plink.log ]
# Analysis started: Tue Mar 15 03:13:54 2016
#
# Options in effect:
# 	--bfile lepto_selected_chr_pruned
# 	--assoc
#
# Reading map (extended format) from [ lepto_selected_chr_pruned.bim ]
# 3107 markers to be included from [ lepto_selected_chr_pruned.bim ]
# Reading pedigree information from [ lepto_selected_chr_pruned.fam ]
# ...
