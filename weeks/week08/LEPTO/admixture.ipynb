# %%
# %%bash
# #running admixture on lepto with 2 clusters
# /projects/ps-yeolab/biom262_2016/tools/admixture_linux-1.3.0/admixture --cv lepto_selected_chr_pruned.bed 2
# Out:
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 266x3107
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 0.103	Loglikelihood: -573409	(delta): 851072
# ...

# %%
# %%bash
# #running admixture on lepto_unrel with 2 clusters
# /projects/ps-yeolab/biom262_2016/tools/admixture_linux-1.3.0/admixture --cv lepto_selected_chr_pruned.bed 3
# Out:
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 266x3107
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 0.146	Loglikelihood: -579660	(delta): 746621
# ...

# %%
# %%bash
# #running admixture on lepto with 4 clusters
# /projects/ps-yeolab/biom262_2016/tools/admixture_linux-1.3.0/admixture --cv lepto_selected_chr_pruned.bed 4
# Out:
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 266x3107
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 0.16	Loglikelihood: -582018	(delta): 705648
# ...

# %%
# %%bash
# #running admixture on lepto_unrel with 5 clusters
# /projects/ps-yeolab/biom262_2016/tools/admixture_linux-1.3.0/admixture --cv lepto_selected_chr_pruned.bed 5
# Out:
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 266x3107
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 0.19	Loglikelihood: -581868	(delta): 681181
# ...

# %%
# %%bash
# #running admixture on lepto_unrel with 6 clusters
# /projects/ps-yeolab/biom262_2016/tools/admixture_linux-1.3.0/admixture --cv lepto_selected_chr_pruned.bed 6
# Out:
# ****                   ADMIXTURE Version 1.3.0                  ****
# ****                    Copyright 2008-2015                     ****
# ****           David Alexander, Suyash Shringarpure,            ****
# ****                John  Novembre, Ken Lange                   ****
# ****                                                            ****
# ****                 Please cite our paper!                     ****
# ****   Information at www.genetics.ucla.edu/software/admixture  ****
#
# Cross-validation will be performed.  Folds=5.
# Random seed: 43
# Point estimation method: Block relaxation algorithm
# Convergence acceleration algorithm: QuasiNewton, 3 secant conditions
# Point estimation will terminate when objective function delta < 0.0001
# Estimation of standard errors disabled; will compute point estimates only.
# Size of G: 266x3107
# Performing five EM steps to prime main algorithm
# 1 (EM) 	Elapsed: 0.203	Loglikelihood: -579657	(delta): 662131
# ...

# %%
'''Based on CV error values, 3 clusters seem to be best. Which also makes sense because we have three refecrence values'''

# %%
# %%bash
#
# grep

# %%
assoc
# Out:
#       CHR                       SNP         BP   A1      F_A      F_U   A2        CHISQ            P           OR
# 0       17                 rs8078929      78232    A...
# 1       17                 rs4968145     402564    G...
# 2       17              vh_17_473657     473657    A...
# 3       17                 rs8082184     690979    G...
# 4       17                 rs7218037     716217    G...
# 5       17                 rs9892880     731386    A...
# 6       17                 rs1979988     774976    A...
# 7       17                 rs2586238     849072    A...
# 8       17             imm_17_906036     906036    G...
# 9       17                 rs9916862     984938    A...
# 10      17                 rs8081687    1040869    A...
# 11      17                 rs4968185    1061660    G...
# 12      17                rs10852857    1302301    A...
# 13      17                  rs939562    1347642    G...
# 14      17                 rs4790666    1440465    A...
# ...
